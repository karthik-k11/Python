# %% [markdown]
# ### This notebook contains the basic programs of python

# %%
print("Hello World")
# Out:
# Hello World

# %%
x=8
y= 'Karthik'
print(x)
print(y)
# Out:
# 8
# Karthik

# %%
x=7
x='Karthik'
print(x)
# Out:
# Karthik

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
x,y,z= 'Karthik', 'Virat', 'Kohli'
print(x)
print(y)
print(z)
# Out:
# Karthik
# Virat
# Kohli

# %%
x=y=z='Karthik'
print(x)
print(y)
print(z)
# Out:
# Karthik
# Karthik
# Karthik

# %%
x='I will'
y='Become a'
z= 'Pro in Python'
print(x,y,z)
# Out:
# I will Become a Pro in Python

# %%
x=1 #int
y=0.3 #float
z=1j #complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# **Casting**

# %%
x= int(2)
y= int(7.3)
z= int('3')
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# **Strings**

# %%
##Quotes inside quotes
print("Hello this is 'Karthik'")
print("It's Ok")
# Out:
# Hello this is 'Karthik'
# It's Ok

# %%
a= "Hello"
print(a)
# Out:
# Hello

# %%
a= '''Hii
My name is Karthik'''
print(a)
# Out:
# Hii
# My name is Karthik

# %% [markdown]
# - Slicing Strings

# %%
m=(" What is your name? ")
print(m[2:5])
# Out:
# hat

# %% [markdown]
# - Slicing From start

# %%
print(m[:5])
# Out:
#  What

# %% [markdown]
# - Modifying Strings

# %%
##Upper case
print(m.upper())
# Out:
#  WHAT IS YOUR NAME?

# %%
##Lower case
print(m.lower())
# Out:
#  what is your name?

# %%
##Removing Whitespace
print(m.strip())
# Out:
# What is your name?

# %%
##Replace String
print(m.replace("W", "H"))
# Out:
#  Hhat is your name?

# %%
##Splitting
print(m.split(" "))
# Out:
# ['', 'What', 'is', 'your', 'name?', '']

# %% [markdown]
# - String Concatenation

# %%
##Merging strings
a= "Python"
b= "Programming"
c="Language"
print(a+b+c)
# Out:
# PythonProgrammingLanguage

# %%
##Adding Whitespace
print(a+ " "+ b+ " "+c)
# Out:
# Python Programming Language

# %% [markdown]
# - Format Strings

# %%
package= 500000
t= f"My Package is {package} "
print(t)
# Out:
# My Package is 500000

# %%
salary= 40000
s= "My Salary is "
print(s, salary)
# Out:
# My Salary is  40000

# %%
time= 9.07
print(f"The Time now is {time}")
# Out:
# The Time now is 9.07

# %% [markdown]
# - Escape Characters

# %%
##Backslash
print("Hardwork is the \"only\" way to success")
# Out:
# Hardwork is the "only" way to success

# %%
##Newline
print("Hi \nHello")
# Out:
# Hi
# Hello

# %% [markdown]
# - String Methods

# %%
##Capitalize
text= "consistency is the Key"
k= text.capitalize()
print(k)
# Out:
# Consistency is the key

# %%
##Casefold
l= text.casefold()
print(l)
# Out:
# consistency is the key

# %%
o=text.center(100)
print(o)
# Out:
#                                        consistency is the Key

# %% [markdown]
# Strings are arrays:

# %%
a= "Hello, World"
print(a[1])
# Out:
# e

# %% [markdown]
# **Boolean**

# %%
print(7<11)
print(16>17)
print(11==11)
# Out:
# True
# False
# True

# %%
from collections import Counter

# %% [markdown]
# About this library:
#
# - **collections** is a built-in Python module that gives special super-powered data structures.
# - **Counter** is a counting dictionary, It automatically cpounts how many time each item appears
#
# eg:

# %%
data = ['a', 'b', 'c', 'a', 'b', 'b']

count= Counter(data)
print(count)
# Out:
# Counter({'b': 3, 'a': 2, 'c': 1})

# %% [markdown]
# **Weapons**
# 1. String Weapons

# %%
text= "racecar"
##Reverse
print(f"Reversed string: {text[::-1]}")
##Palindrome
print(f"Is this word is a palindrome: {[text==text[::-1]]}")
# Out:
# Reversed string: racecar
# Is this word is a palindrome: [True]

# %%
##Join List into string
words= ["Hello", "World"]
print(f"Joined list: {'_'.join(words)}")
# Out:
# Joined list: Hello_World

# %% [markdown]
# 2. LIST Weapons

# %%
##Remove duplicates in a list
nums= [1, 2, 2, 3, 4, 5, 5, 6]
unique= list(set(nums))
print(f"Duplicates Removed {unique}")
# Out:
# Duplicates Removed [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **enumerate() function**

# %%
##Looping with Index
for index, value in enumerate(words):
    print(f"Index: {index}, Value: {value}")
# Out:
# Index: 0, Value: Hello
# Index: 1, Value: World

# %% [markdown]
# 3. Dictionary Weapons

# %%
##Anagram
##Will use Counter to solve instantly
str1= "heart"
str2= "earth"
print(f"Is anagram:  {Counter(str1)==Counter(str2)}")
# Out:
# Is anagram:  True

# %%
##Using .get() to get safety against errors
my_dict= {"a":1, "b": 2}
counts= my_dict.get("b", 2)
print(f"Safe Counts: {counts}")
# Out:
# Safe Counts: 2

# %%
##Returns 0 instead of errors 
my_dict2= {"a":1, "b": 2}
count= my_dict2.get("c", 0)
print(f"Safe Count: {count}")
# Out:
# Safe Count: 0

# %% [markdown]
# 4. MATH / LoGIC SHORTCUTS

# %%
vals=[True, True, False]
print(f"All True ? {all(vals)}")
print(f"Any True ? {any(vals)}")
# Out:
# All True ? False
# Any True ? True

# %%
list1=[1, 2, 3]
list2= [10, 20, 30]
#Zip two lists together 
for a, b in zip(list1, list2):
    print(f"Pair: {a}-{b}")
# Out:
# Pair: 1-10
# Pair: 2-20
# Pair: 3-30
