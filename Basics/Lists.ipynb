# %% [markdown]
# ## **Python Lists**
#
# - A dynamic array, used to store multiple items is a single variable.
# - List items are:
#     - Ordered (items have defined order, If we add new it will be placed at the end)
#     - Changable
#     - Allows duplicate values
#
# - Fast indexing
# - But shifting is expensive

# %%
mylist= [10, 20, 40, "Lion", True, 30, 90, 10, 40]  #Can be of different datatypes
print(mylist)
# Out:
# [10, 20, 40, 'Lion', True, 30, 90, 10, 40]

# %%
##Length of list
print(len(mylist))
# Out:
# 9

# %%
print(type(mylist))
# Out:
# <class 'list'>

# %%
##Indexing
print(mylist[0])
# Out:
# 10

# %%
print(mylist[1])
# Out:
# 20

# %%
##Negative indexing = reverse traversal 
print(mylist[-1])
# Out:
# 40

# %% [markdown]
# - ### Traversing list

# %%
##Index based traversing (for two pointers, binary search, etc..)
for i in range(len(mylist)):  
    print(mylist[i])
# Out:
# 10
# 20
# 40
# Lion
# True
# 30
# 90
# 10
# 40

# %%
##Value based 
for x in mylist:
    print(x)
# Out:
# 10
# 20
# 40
# Lion
# True
# 30
# 90
# 10
# 40

# %%
##Accessing by range of indexes
print(mylist[2:5])    # 2 included, 5 not included
# Out:
# [40, 'Lion', True]

# %%
print(mylist[:4])  #From beginning, not includes 4
# Out:
# [10, 20, 40, 'Lion']

# %%
print(mylist[3:])
# Out:
# ['Lion', True, 30, 90, 10, 40]

# %% [markdown]
# - Changing list items

# %%
mylist[2]=30
print(mylist)
# Out:
# [10, 20, 30, 'Lion', True, 30, 90, 10, 40]

# %%
mylist[4:7]= False, 20, 80
print(mylist)
# Out:
# [10, 20, 30, 'Lion', False, 20, 80, 10, 40]

# %% [markdown]
# - Adding List Items

# %%
##Adds at the end
mylist.append("Lakshmi")
print(mylist)
# Out:
# [10, 20, 30, 'Lion', False, 20, 80, 10, 40, 'Lakshmi']

# %%
mylist.append(60)
print(mylist)
# Out:
# [10, 20, 30, 'Lion', False, 20, 80, 10, 40, 'Lakshmi', 60]

# %%
#Inserting at a specific index
mylist.insert(4, 40)
print(mylist)
# Out:
# [10, 20, 30, 'Lion', 40, False, 20, 80, 10, 40, 'Lakshmi', 60]

# %% [markdown]
# - Removing

# %%
##Removes last item
mylist.pop()
print(mylist)
# Out:
# [10, 20, 30, 'Lion', 40, False, 20, 80, 10, 40, 'Lakshmi']

# %%
#Remove the specific item
mylist.remove(40)
print(mylist)
# Out:
# [10, 20, 30, 'Lion', False, 20, 80, 10, 40, 'Lakshmi']

# %%
##What if there are duplicates
mylist.remove(20)
print(mylist, "Deletes the first Occurence")
# Out:
# [10, 30, 'Lion', False, 20, 80, 10, 40, 'Lakshmi'] Deletes the first Occurence
